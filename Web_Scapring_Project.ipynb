# %%
from bs4 import BeautifulSoup

import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue'

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, 'html')

# %%
table = soup.find_all('table')[1]

# %%
world_titles = table.find_all('th')

# %%
table_titles = [title.text.strip() for title in world_titles]

# %%
print(table_titles)
# Out:
# ['Rank', 'Name', 'Industry', 'Revenue (USD billions)', 'Employees', 'Headquarters']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = table_titles)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Revenue (USD billions), Employees, Headquarters]
# Index: []

# %%
column_table= table.find_all('tr')

# %%
for row in column_table[1:]:
    row_data = row.find_all('td')
    indiv_row_data = [ data.text.strip() for data in row_data]
  
    length = len(df)
    df.loc[length] = indiv_row_data

# %%
df
# Out:
#    Rank                                Name                       Industry  \
# 0     1                             Cargill                  Food industry
# 1     2                     Koch Industries                   Conglomerate
# 2     3                Publix Super Markets                         Retail
# 3     4                  Mars, Incorporated                  Food industry
# 4     5                               H-E-B                         Retail
# 5     6                      Reyes Holdings                    Wholesaling
# 6     7                 Enterprise Holdings                     Car rental
# 7     8               C&S Wholesale Grocers                    Wholesaling
# 8     9                              Love's  Petroleum industry and Retail
# 9    10  Southern Glazer's Wine and Spirits                  Food industry
# 10    1                             Cargill                  Food industry
# 11    2                     Koch Industries                   Conglomerate
# 12    3                Publix Super Markets                         Retail
# 13    4                  Mars, Incorporated                  Food industry
# 14    5                               H-E-B                         Retail
# 15    6                      Reyes Holdings                    Wholesaling
# 16    7                 Enterprise Holdings                     Car rental
# 17    8               C&S Wholesale Grocers                    Wholesaling
# 18    9                              Love's  Petroleum industry and Retail
# 19   10  Southern Glazer's Wine and Spirits                  Food industry
# 20    1                             Cargill                  Food industry
# 21    2                     Koch Industries                   Conglomerate
# 22    3                Publix Super Markets                         Retail
# 23    4                  Mars, Incorporated                  Food industry
# 24    5                               H-E-B                         Retail
# 25    6                      Reyes Holdings                    Wholesaling
# 26    7                 Enterprise Holdings                     Car rental
# 27    8               C&S Wholesale Grocers                    Wholesaling
# 28    9                              Love's  Petroleum industry and Retail
# 29   10  Southern Glazer's Wine and Spirits                  Food industry
#
#    Revenue (USD billions) Employees             Headquarters
# 0                     177   160,000    Minnetonka, Minnesota
# 1                     125   120,000          Wichita, Kansas
# 2                    54.5   250,000        Lakeland, Florida
# 3                      47   140,000         McLean, Virginia
# 4                    43.6   145,000       San Antonio, Texas
# 5                      40    36,000       Rosemont, Illinois
# 6                      35    90,000        Clayton, Missouri
# 7                    34.7    15,000     Keene, New Hampshire
# 8                    26.5    40,000  Oklahoma City, Oklahoma
# 9                    26.0    24,000         Miramar, Florida
# 10                    177   160,000    Minnetonka, Minnesota
# 11                    125   120,000          Wichita, Kansas
# 12                   54.5   250,000        Lakeland, Florida
# 13                     47   140,000         McLean, Virginia
# 14                   43.6   145,000       San Antonio, Texas
# 15                     40    36,000       Rosemont, Illinois
# 16                     35    90,000        Clayton, Missouri
# 17                   34.7    15,000     Keene, New Hampshire
# 18                   26.5    40,000  Oklahoma City, Oklahoma
# 19                   26.0    24,000         Miramar, Florida
# 20                    177   160,000    Minnetonka, Minnesota
# 21                    125   120,000          Wichita, Kansas
# 22                   54.5   250,000        Lakeland, Florida
# 23                     47   140,000         McLean, Virginia
# 24                   43.6   145,000       San Antonio, Texas
# 25                     40    36,000       Rosemont, Illinois
# 26                     35    90,000        Clayton, Missouri
# 27                   34.7    15,000     Keene, New Hampshire
# 28                   26.5    40,000  Oklahoma City, Oklahoma
# 29                   26.0    24,000         Miramar, Florida
